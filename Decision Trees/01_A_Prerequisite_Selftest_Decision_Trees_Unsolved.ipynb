# %% [markdown]
# # Selftest - Breast Cancer Classification with Decision Trees
#
# **Background:**
# In this task you will use a classic medical dataset (Breast Cancer Wisconsin Diagnostic) to train a decision tree classifier. The dataset contains features computed from digitized images of breast mass cell nuclei.
#
# **Task Overview:**
# Fit a decision tree classifier, and evaluate training and validation accuracy.
#
# **Dataset:**
# We use the Breast Cancer Wisconsin (Diagnostic) dataset available via scikit-learn. It contains 30 real-valued features describing cell nuclei and a binary target indicating benign (0) or malignant (1) tumors.

# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# Add additional packages here if needed

# %%
cancer = datasets.load_breast_cancer()

# %% [markdown]
# We convert the scikit-learn dataset into a pandas DataFrame to inspect feature names and a few malignant samples. The DataFrame contains 30 feature columns plus the target column where `1` indicates malignant and `0` benign.

# %%
df = pd.DataFrame(np.c_[cancer['data'], cancer['target']],
                  columns= np.append(cancer['feature_names'], ['target']))
df.loc[df['target']==1].head(10)

# %% [markdown]
# Perform a split of `cancer` into training and validation data with the validation data accounting for 30% of the total dataset.

# %%
# your code goes here

# %% [markdown]
# Train a decision tree using the training dataset.

# %%
# your code goes here

# %% [markdown]
# Compute the training and validation accuracy and print it.

# %%
# your code goes here
